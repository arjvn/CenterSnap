# %%
img_full_path = '/nfs/aiteam/arjun/Development/leap/CenterSnap/realsense_capture/avocado_test/0100'

from matplotlib import pyplot as plt
# read image with matplotlib
img = plt.imread(img_full_path + '_depth.png')
img = img[:,:,0]
plt.imshow(img)
plt.show()
# get shape, min and max
print(img.shape, img.min(), img.max())

# Save the img variable as an image file
plt.imsave(img_full_path+'_real_depth.png', img)

img_full_path = '/nfs/aiteam/arjun/Development/leap/CenterSnap/nocs_test_subset/Real/test/scene_1/0006'

from matplotlib import pyplot as plt
# read image with matplotlib
img = plt.imread(img_full_path + '_depth.png')
plt.imshow(img)
plt.show()

# get shape, min and max
print(img.shape, img.min(), img.max())
# Out:
# (480, 640) 0.0 1.0
# (480, 640) 0.0 0.017547876
